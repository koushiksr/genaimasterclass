# %%
import os
import glob
import tiktoken
import numpy as np
from dotenv import load_dotenv
from langchain_openai import OpenAIEmbeddings
from langchain_chroma import Chroma
# from langchain_huggingface import HuggingFaceEmbeddings
from langchain_community.document_loaders import DirectoryLoader, TextLoader
from langchain_text_splitters import RecursiveCharacterTextSplitter
from sklearn.manifold import TSNE
import plotly.graph_objects as go
# Out:
# /var/folders/s_/2xfqdh_j1pl0bdbycvv8y7n40000gn/T/ipykernel_68153/733423580.py:9: DeprecationWarning: `langchain-community` is being sunset and is no longer actively maintained. See https://github.com/langchain-ai/langchain-community/issues/674 for details and migration guidance toward standalone integration packages.
#   from langchain_community.document_loaders import DirectoryLoader, TextLoader

# %%
MODEL = "gpt-4.1-mini"
db_name = "vector_db"
load_dotenv(override=True)
openai_api_key = os.getenv('OPENAI_API_KEY')
if openai_api_key:
    print(f"OpenAI API Key exists and begins {openai_api_key[:8]}")
else:
    print("OpenAI API Key not set")
# Out:
# OpenAI API Key exists and begins sk-proj-

# %%
knowledge_base_path = "/Users/pramodramamurthy/Downloads/Agents/knowledge-base/**/*.md"
files = glob.glob(knowledge_base_path, recursive=True)
print(f"Found {len(files)} files in the knowledge base")

entire_knowledge_base = ""

for file_path in files:
    with open(file_path, 'r', encoding='utf-8') as f:
        entire_knowledge_base += f.read()
        entire_knowledge_base += "\n\n"

print(f"Total characters in knowledge base: {len(entire_knowledge_base):,}")
# Out:
# Found 76 files in the knowledge base
# Total characters in knowledge base: 304,434

# %%
encoding = tiktoken.encoding_for_model(MODEL)
tokens = encoding.encode(entire_knowledge_base)
token_count = len(tokens)
print(f"Total tokens is {MODEL}: {token_count}")
# Out:
# Total tokens is gpt-4.1-mini: 63555

# %%
#LangChain Framework
#Chunking
#Embedding
#Vector Database -- Chroma
