# %%
import os
from dotenv import load_dotenv
from scrapper import fetch_website_contents
from openai import OpenAI

# %%
load_dotenv(override=True)

openapi_key = os.getenv('OPENAI_API_KEY')
google_api_key = os.getenv('GOOGLE_API_KEY')
groq_api_key = os.getenv('GROQ_API_KEY')

if not openapi_key:
    print("No API key found")
elif not openapi_key.startswith("sk-proj"):
    print("API Key not found, it doesnt start with sk-proj")
else:
    print("API key found and looks good")

if not google_api_key:
    print("No API key found")
else:
    print("Google API key found and looks good")
# Out:
# API key found and looks good
# Google API key found and looks good

# %%
gemini_url = "https://generativelanguage.googleapis.com/v1beta/openai/"
groq_url = "https://api.groq.com/openai/v1"
ollama_url = "http://localhost:11434/v1"
# anthropic_url = "https://api.anthropic.com/v1/"
# grok_url = "https://api.x.ai/v1"
# openrouter_url = "https://openrouter.ai/api/v1"


openai = OpenAI()
gemini = OpenAI(api_key=google_api_key, base_url=gemini_url)
groq = OpenAI(api_key=groq_api_key, base_url=groq_url)
ollama = OpenAI(api_key="ollama", base_url=ollama_url)
# anthropic = OpenAI(api_key=anthropic_api_key, base_url=anthropic_url)
# grok = OpenAI(api_key=grok_api_key, base_url=grok_url)
# openrouter = OpenAI(base_url=openrouter_url, api_key=openrouter_api_key)
# deepseek = OpenAI(api_key=deepseek_api_key, base_url=deepseek_url)

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Pramod!"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
response.choices[0].message.content
# Out:
# 'Hello Pramod! How can I assist you today?'

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
response.choices[0].message.content
# Out:
# 'I’m sorry, but I don’t know your name. Could you please tell me?'

# %%
messages = [
    {"role": "system", "content": "You are a helpful assistant"},
    {"role": "user", "content": "Hi! I'm Pramod!"},
    {"role": "assistant", "content": "Hi Pramod! How can I assist you today?"},
    {"role": "user", "content": "What's my name?"}
    ]

# %%
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
response.choices[0].message.content
# Out:
# 'Your name is Pramod! How can I help you further?'

# %% [markdown]
# 1. Every Call to an LLM is stateless
# 2. We pass in the entire conversation as a prompt back to LLM
# 3. This gives an illusion of Memory
