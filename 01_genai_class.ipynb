# %%
print("Hello World")
# Out:
# Hello World

# %%
import os
from dotenv import load_dotenv
from openai import OpenAI

# %%
load_dotenv(override=True)

api_key = os.getenv('OPENAI_API_KEY')

if not api_key:
    print("No API key found")
elif not api_key.startswith("sk-proj"):
    print("API Key not found, it doesnt start with sk-proj")
else:
    print("API key found and looks good")
# Out:
# API key found and looks good

# %%
message = "Hello GPT! This is my first ever message to you! Hi"
messages = [{"role": "user", "content":message}]
print(messages)
# Out:
# [{'role': 'user', 'content': 'Hello GPT! This is my first ever message to you! Hi'}]

# %%
openai = OpenAI()

#Chat Completions model
response = openai.chat.completions.create(model="gpt-4.1-mini", messages=messages)
response.choices[0].message.content
# Out:
# 'Hello! Welcome and thanks for your message! How can I assist you today? :)'

# %%
#llama3.2
# ollama pull llama3.2
# ollama serve

# %%
from openai import OpenAI

OLLAMA_BASE_URL = "http://localhost:11434/v1"
MODEL = "llama3.2"

ollama = OpenAI(base_url= OLLAMA_BASE_URL, api_key= "ollama")
response = ollama.chat.completions.create(model=MODEL, messages=messages)
print(response.choices[0].message.content)
# Out:
# Welcome to our conversation. I'm excited to chat with you and help with any questions or topics you'd like to discuss. Don't worry if you're not sure where to start – we can take it one step at a time.
#
# How's your day going so far? Would you like to talk about something in particular, or is there anything on your mind that you'd like to explore? I'm all ears!

# %%
from re import X
from pandas._libs.groupby import group_quantile


Google -- Gemini
Groq -- groq
grok - X
Anthropic - claude models
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[21], line 2
#       1 from re import X
# ----> 2 from pandas._libs.groupby import group_quantile
#       3
#       4
#       5 Google -- Gemini
#
# File ~/Downloads/microdegree/.venv/lib/python3.12/site-packages/pandas/__init__.py:44
#      34 from pandas._config import (
#      35     get_option,
#      36     set_option,
#    (...)     40     options,
#      41 )
#      43 # let init-time option registration happen
# ---> 44 import pandas.core.config_init  # pyright: ignore[reportUnusedImport] # noqa: F401
#      46 from pandas.core.api import (
#      47     # dtype
#      48     ArrowDtype,
#    (...)    107     DataFrame,
#     108 )
#     109 from pandas.core.col import col
#
# File ~/Downloads/microdegree/.venv/lib/python3.12/site-packages/pandas/core/config_init.py:31
#      19 import pandas._config.config as cf
#      20 from pandas._config.config import (
#      21     is_bool,
#      22     is_callable,
#    (...)     28     is_text,
#      29 )
# ---> 31 from pandas.errors import Pandas4Warning
#      33 # compute
#      35 use_bottleneck_doc = """
#      36 : bool
#      37     Use the bottleneck library to accelerate if it is installed,
#      38     the default is True
#      39     Valid values: False,True
#      40 """
#
# File ~/Downloads/microdegree/.venv/lib/python3.12/site-packages/pandas/errors/__init__.py:12
#       8 import ctypes
#      10 from pandas._config.config import OptionError
# ---> 12 from pandas._libs.tslibs import (
#      13     IncompatibleFrequency,
#      14     OutOfBoundsDatetime,
#      15     OutOfBoundsTimedelta,
#      16 )
#      18 from pandas.util.version import InvalidVersion
#      21 class IntCastingNaNError(ValueError):
#
# File ~/Downloads/microdegree/.venv/lib/python3.12/site-packages/pandas/_libs/__init__.py:18
#      16 import pandas._libs.pandas_parser  # isort: skip # type: ignore[reportUnusedImport]
#      17 import pandas._libs.pandas_datetime  # noqa: F401 # isort: skip # type: ignore[reportUnusedImport]
# ---> 18 from pandas._libs.interval import Interval
#      19 from pandas._libs.tslibs import (
#      20     NaT,
#      21     NaTType,
#    (...)     26     iNaT,
#      27 )
#
# File pandas/_libs/interval.pyx:1, in init pandas._libs.interval()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/hashtable.pyx:1, in init pandas._libs.hashtable()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File pandas/_libs/missing.pyx:1, in init pandas._libs.missing()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File ~/Downloads/microdegree/.venv/lib/python3.12/site-packages/pandas/_libs/tslibs/__init__.py:40
#       1 __all__ = [
#       2     "BaseOffset",
#       3     "Day",
#    (...)     37     "tz_convert_from_utc_single",
#      38 ]
# ---> 40 from pandas._libs.tslibs import dtypes
#      41 from pandas._libs.tslibs.conversion import localize_pydatetime
#      42 from pandas._libs.tslibs.dtypes import (
#      43     Resolution,
#      44     periods_per_day,
#      45     periods_per_second,
#      46 )
#
# File pandas/_libs/tslibs/dtypes.pyx:1, in init pandas._libs.tslibs.dtypes()
# ----> 1 'Could not get source, probably due dynamically evaluated source code.'
#
# File <frozen importlib._bootstrap>:645, in ModuleSpec.parent(self)
# --> 645 'Could not get source, probably due dynamically evaluated source code.'
#
# KeyboardInterrupt:
